# %% [markdown]
# <a href="https://colab.research.google.com/github/umarmohammed/measuring-bias-in-a-dataset/blob/project-1/1.%20Load%20the%20HMDA%20dataset%20into%20a%20pandas%20dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive locally
from google.colab import drive
drive.mount('/content/drive')

# %%
# Load the pickled dataframe
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/liveProject/mortgage_data_balanced.pkl.gz")

# %%
# Do a quick inspection of the data
df.head()
# Out:
#    as_of_year  ... application_date_indicator
# 0        2011  ...                          0
# 1        2011  ...                          0
# 2        2011  ...                          0
# 3        2011  ...                          0
# 4        2011  ...                          0
#
# [5 rows x 78 columns]
